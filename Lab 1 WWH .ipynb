# %%
# phyton its compatible with many tools and more firendly to undestand when someone new starts working with certain tools conected 

print (" welcome to data engineering wth phyton")
# Out:
#  welcome to data engineering wth phyton

# %%
print("Step 1: Read data")

print("Step 2: Clean data")

print("Step 3: Write data")
# Out:
# Step 1: Read data
# Step 2: Clean data
# Step 3: Write data

# %%
customer_name = "Asha Patel"
customer_id = 101
active = True
print( f"{customer_name, customer_id}:  (Active: { active} )")
# Out:
# ('Asha Patel', 101):  (Active: True )

# %%
# 1. Assigning the values to variables
v1 = 250
v2 = 99.95
v3 = "Mumbai"
v4 = False
v5 = True

print(f"Value: {v1}, Type: {type(v1)}")
print(f"Value: {v2}, Type: {type(v2)}")
print(f"Value: {v3}, Type: {type(v3)}")
print(f"Value: {v4}, Type: {type(v4)}")
print(F"Value: {v5}, Type: {type(v5)}")
# Out:
# Value: 250, Type: <class 'int'>
# Value: 99.95, Type: <class 'float'>
# Value: Mumbai, Type: <class 'str'>
# Value: False, Type: <class 'bool'>
# Value: True, Type: <class 'bool'>

# %%
mark1 = "78"
mark2 = "85.5"

total = int(mark1) + float(mark2)

print(f"total marks:{total}" )
# Out:
# total marks:163.5

# %%
item_price = 249.99
quantity = 3
tax_rate = 0.05 # 5%

subtotal = item_price * quantity
tax = subtotal * tax_rate
grand_total = subtotal + tax

print  (f" grant total: {grand_total:.2f}")
# Out:
#  grant total: 787.47

# %%
order1 = 1200
order2 = 999
if(order1 > order2):
    print("order one it greater")
if(order1 == order2):
    print("order two and one are equals")
else: print("they are not equals")
# Out:
# order one it greater
# they are not equals

# %%
order1 = 1200
order2 = 999

is_greater = order1 > order2
are_equal = order1 == order2

print(f"Is order1 > order2? {is_greater}")
print(f"Are order1 and order2 equal? {are_equal}")
# Out:
# Is order1 > order2? True
# Are order1 and order2 equal? False

# %%
price = 1500
in_stock = True

HV_InStock = (price > 1000) and (in_stock== True)
Hv_OutStock = (price>1000) or (not in_stock)

print (F"High value item available? {HV_InStock} ")
print (F"High value or out of stock  {Hv_OutStock}")

#it gives both true since it ask in the second one if high value or out of stock and since one of them its ture then its ture
# Out:
# High value item available? True
# High value or out of stock  True

# %%
Name = input ("Enter customer name")
amount = input("Enter purchase amount")

amount = float(amount)


print (f" Recipt: {Name} ,Amount {amount:.2f}")
# Out:
# Enter customer name gincarlo guardian das univezo eh de esspacio
# Enter purchase amount 22
#  Recipt: gincarlo guardian das univezo eh de esspacio ,Amount 22.00

# %%
product = "SSD"
price = 12999.5
qty = 2

print(f" order: {qty} x {product} @ {price:.2f} each --- total:{price*qty:.2f}")

#since a float + a int its always a float i did not saw the need to declare total
# Out:
#  order: 2 x SSD @ 12999.50 each --- total:25999.00

# %%
name = "Neha"
print(name)  # typo


age = 30
print(f" Age next year: {age + 1}")


value = "123"
num = int(value)
print(num)
# Out:
# Neha
#  Age next year: 31
# 123

# %%
original_price = 4999.99
discount_percent = 12.5

discount_amount = original_price * (discount_percent / 100)
final_price = original_price - discount_amount



print(f"Discount: {discount_amount:.2f}")
print(f"Final Price: {final_price:.2f}")
# Out:
# Discount: 625.00
# Final Price: 4374.99

# %%
name = "Rohan Verma"
id = "205"
item = "Textbook"
unit_price = "450.5"
quantity = "2"


student_id = int(id)
price = float(unit_price)
qty = int(quantity)

subtotal = price * qty
tax = subtotal * 0.05
grand_total = subtotal + tax

print(f"Customer ID: {student_id}")
print(f"Customer Name: {name}")
print(f"Item: {item}")
print(f"Quantity: {qty}")
print(f"Subtotal: {subtotal:.2f}")
print(f"Tax (5%): {tax:.2f}")
print(f"Grand Total: {grand_total:.2f}")
# Out:
# Customer ID: 205
# Customer Name: Rohan Verma
# Item: Textbook
# Quantity: 2
# Subtotal: 901.00
# Tax (5%): 45.05
# Grand Total: 946.05
